# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/energy_iter11.csv')

df["Date"]=pd.to_datetime(df["Date"])

# %%
df.describe()
# Out:
#                                 Date    Demand(MW)  Generation(MW)  \
# count                           1636   1636.000000     1636.000000
# mean   2022-09-10 00:34:19.657701888  12290.974328    14130.438875
# min              2020-06-02 00:00:00   7800.000000     9482.000000
# 25%              2021-07-18 18:00:00  10700.000000    13182.000000
# 50%              2022-09-07 12:00:00  12400.000000    14448.000000
# 75%              2023-10-28 06:00:00  13900.000000    15202.000000
# max              2024-12-31 00:00:00  17300.000000    17638.000000
# std                              NaN   1977.969132     1526.740541
#
#            Temp(C)         Year        Month       Season    IsHoliday  \
# count  1636.000000  1636.000000  1636.000000  1636.000000  1636.000000
# mean     27.262592  2022.163203     6.863081     0.678484     0.146699
# min      14.000000  2020.000000     1.000000     0.000000     0.000000
# 25%      25.000000  2021.000000     4.000000     0.000000     0.000000
# ...

# %%
df.tail(2)
# Out:
#            Date  Demand(MW)  Generation(MW)  Temp(C)  Year  Month  Season  \
# 1634 2020-06-03       11000           14747     28.9  2020      6       1
# 1635 2020-06-02       11000           14765     29.5  2020      6       1
#
#       IsHoliday  DemandGenGap(MW)
# 1634          0              3747
# 1635          0              3765

# %% [markdown]
# # **Remove Outliers**

# %%
# Temperature
Q1 = df["Temp(C)"].quantile(0.25)
Q3 = df["Temp(C)"].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

for i in range (100):
  outliers =(df['Temp(C)']<lower_bound) | (df['Temp(C)']>upper_bound)

  if not outliers.any():
    print(f"break loop")
    break

df["Temp(C)"]=df['Temp(C)'].mask(outliers,df['Temp(C)'].rolling(window=10,center=True,min_periods=1).mean())
# Out:
# break loop

# %%
#Temperature outlier check after removal

Q1 = df["Temp(C)"].quantile(0.25)
Q3 = df["Temp(C)"].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = df[(df["Temp(C)"] < lower_bound) | (df["Temp(C)"] > upper_bound)]
num_outliers = outliers.shape[0]
print(f"Number of outliers in Temp(C): {num_outliers}")
# Out:
# Number of outliers in Temp(C): 0

# %%
#save dataset
df.to_csv('energy_iter13c.csv',index=False)
print("saved with clean data")
# Out:
# saved with clean data

# %%
# Outliers removal for Generation

Q1 = df["Generation(MW)"].quantile(0.25)
Q3 = df["Generation(MW)"].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

for i in range (100):
  outliers =(df['Generation(MW)']<lower_bound) | (df['Generation(MW)']>upper_bound)

  if not outliers.any():
    print(f"break loop")
    break

df["Generation(MW)"]=df['Generation(MW)'].mask(outliers,df['Generation(MW)'].rolling(window=7,center=True,min_periods=1).mean())
# Out:
# break loop

# %%
#Generation outliers check after removal

Q1 = df["Generation(MW)"].quantile(0.25)
Q3 = df["Generation(MW)"].quantile(0.75)
IQR = Q3 - Q1


lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = df[(df["Generation(MW)"] < lower_bound) | (df["Generation(MW)"] > upper_bound)]
num_outliers = outliers.shape[0]
print(f"Number of outliers in Generation(MW):{num_outliers}")
# Out:
# Number of outliers in Generation(MW):0

# %%
#save dataset
df.to_csv('energy_iter13c.csv',index=False)
print("saved with clean data")
# Out:
# saved with clean data

# %%
#we dont have any outlier in Demand .So ,we don't need to perform outlier removal operation for this
#Day Peak Generation outlier check

Q1 = df["Demand(MW)"].quantile(0.25)
Q3 = df["Demand(MW)"].quantile(0.75)
IQR = Q3 - Q1


lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = df[(df["Demand(MW)"] < lower_bound) | (df["Demand(MW)"] > upper_bound)]
num_outliers = outliers.shape[0]
print(f"Number of outliers in Demand(MW): {num_outliers}")
# Out:
# Number of outliers in Demand(MW): 0

# %%
df.describe()
# Out:
#                                 Date    Demand(MW)  Generation(MW)  \
# count                           1636   1636.000000     1636.000000
# mean   2022-09-10 00:34:19.657701888  12290.974328    14134.058280
# min              2020-06-02 00:00:00   7800.000000    10154.600164
# 25%              2021-07-18 18:00:00  10700.000000    13182.000000
# 50%              2022-09-07 12:00:00  12400.000000    14448.000000
# 75%              2023-10-28 06:00:00  13900.000000    15202.000000
# max              2024-12-31 00:00:00  17300.000000    17638.000000
# std                              NaN   1977.969132     1516.896902
#
#            Temp(C)         Year        Month       Season    IsHoliday  \
# count  1636.000000  1636.000000  1636.000000  1636.000000  1636.000000
# mean     27.285491  2022.163203     6.863081     0.678484     0.146699
# min      17.500000  2020.000000     1.000000     0.000000     0.000000
# 25%      25.000000  2021.000000     4.000000     0.000000     0.000000
# ...

# %% [markdown]
# # **Z-Score Normalization**

# %%
from sklearn.preprocessing import StandardScaler

# %%
#Standard Scaler

from sklearn.preprocessing import StandardScaler

features=["Demand(MW)","Generation(MW)","Temp(C)","DemandGenGap(MW)"]
scaler=StandardScaler()
df[features]=scaler.fit_transform(df[features])

print("scaled done")
# Out:
# scaled done

# %%
# Save the scaler For future reverse transformation(Scaling values to original values)

import joblib
joblib.dump(scaler,"StandardScaler2c.pkl")
# Out:
# ['StandardScaler2c.pkl']

# %%
df.head()
# Out:
#         Date  Demand(MW)  Generation(MW)   Temp(C)  Year  Month  Season  \
# 0 2024-12-31   -0.855166        0.537407 -2.304651  2024     12       0
# 1 2024-12-30   -0.754021        0.884273 -1.472501  2024     12       0
# 2 2024-12-29   -0.754021        0.392330 -1.633562  2024     12       0
# 3 2024-12-28   -1.234458        0.236042 -1.633562  2024     12       0
# 4 2024-12-27   -0.855166        0.187903 -1.579875  2024     12       0
#
#    IsHoliday  DemandGenGap(MW)
# 0          0          1.588629
# 1          0          1.794999
# 2          0          1.322754
# 3          0          1.774109
# 4          1          1.253119

# %%
#save dataset
df.to_csv('energy_iter13c.csv',index=False)
print("saved with clean data")
# Out:
# saved with clean data
