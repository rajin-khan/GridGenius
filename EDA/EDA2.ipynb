# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### A Sample of the Dataset:

# %%
df = pd.read_csv('./extracted/energy_iter8.csv')
df.head()
# Out:
#          Date  DayPeakGen(MW)  EveningPeakGen(MW)  MaxDemand(MW)  MaxGen(MW)  \
# 0  2024-12-31           14543               14949          10600       14949
# 1  2024-12-31           10596               11883          10100       11883
# 2  2024-12-30           13760               15475          10800       15475
# 3  2024-12-29           14372               14729          10800       14729
# 4  2024-12-28           14138               14492           9850       14492
#
#    Temp(C)  Year  Month         Season IsHoliday
# 0     18.7  2024     12  lowTempSeason        No
# 1     18.7  2024     12  lowTempSeason        No
# 2     21.8  2024     12  lowTempSeason        No
# 3     21.2  2024     12  lowTempSeason        No
# 4     21.2  2024     12  lowTempSeason        No

# %% [markdown]
# ### Null Values in the Dataset:

# %%
df.isnull().sum()
# Out:
# Date                  0
# DayPeakGen(MW)        0
# EveningPeakGen(MW)    0
# MaxDemand(MW)         0
# MaxGen(MW)            0
# Temp(C)               0
# Year                  0
# Month                 0
# Season                0
# IsHoliday             0
# dtype: int64

# %% [markdown]
# ### The different types in our Dataset:

# %%
df.dtypes
# Out:
# Date                   object
# DayPeakGen(MW)          int64
# EveningPeakGen(MW)      int64
# MaxDemand(MW)           int64
# MaxGen(MW)              int64
# Temp(C)               float64
# Year                    int64
# Month                   int64
# Season                 object
# IsHoliday              object
# dtype: object

# %% [markdown]
# ### Handling Duplication:

# %%
#total Number of Duplicates
df.duplicated().sum()
# Out:
# np.int64(13)

# %%
#check for duplicate rows
duplicate_rows = df[df.duplicated()]
print(f"Number of duplicate rows: {duplicate_rows.shape[0]}")
print(duplicate_rows)
# Out:
# Number of duplicate rows: 13
#             Date  DayPeakGen(MW)  EveningPeakGen(MW)  MaxDemand(MW)  \
# 61    2024-11-01           12189               13366          13200
# 185   2024-06-23           15157               17026          15000
# 216   2024-05-23           15537               16810          16000
# 329   2024-01-29           11135               11703          10700
# 336   2024-01-22           10330               11175          10800
# 337   2024-01-22           10330               11175          10800
# 386   2023-11-30           12413               13713          11000
# 509   2023-07-30           13380               15455          15700
# 1137  2021-11-07           12797               14099          10400
# 1165  2021-10-09           13298               14426          12800
# 1179  2021-09-26           13988               14930          13300
# 1434  2021-01-10           12459               13631           9500
# 1436  2021-01-09           12413               13677           9100
#
#       MaxGen(MW)  Temp(C)  Year  Month          Season IsHoliday
# 61         13366     28.8  2024     11   lowTempSeason       Yes
# 185        17026     30.8  2024      6  highTempSeason        No
# 216        16810     31.6  2024      5  highTempSeason        No
# 329        11703     18.2  2024      1   lowTempSeason        No
# 336        11175     14.0  2024      1   lowTempSeason        No
# 337        11175     14.0  2024      1   lowTempSeason        No
# 386        13713     25.3  2023     11   lowTempSeason        No
# 509        15455     31.5  2023      7  highTempSeason        No
# 1137       14099     26.6  2021     11   lowTempSeason        No
# 1165       14426     30.2  2021     10  highTempSeason        No
# 1179       14930     30.8  2021      9  highTempSeason        No
# 1434       13631     22.2  2021      1   lowTempSeason        No
# 1436       13677     22.3  2021      1   lowTempSeason        No

# %%
#remove duplicate values
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Sort chronologically and view:

# %%
#sorting
df = df.sort_values(by='Date', ascending=False)
df.head(10)
# Out:
#          Date  DayPeakGen(MW)  EveningPeakGen(MW)  MaxDemand(MW)  MaxGen(MW)  \
# 0  2024-12-31           14543               14949          10600       14949
# 1  2024-12-31           10596               11883          10100       11883
# 2  2024-12-30           13760               15475          10800       15475
# 3  2024-12-29           14372               14729          10800       14729
# 4  2024-12-28           14138               14492           9850       14492
# 5  2024-12-27           13791               14419          10600       14419
# 6  2024-12-26           13645               14092          10600       14092
# 7  2024-12-25           12982               13683          10500       13683
# 8  2024-12-24           12696               13349          10700       13349
# 9  2024-12-23           12705               13515          10700       13515
#
#    Temp(C)  Year  Month         Season IsHoliday
# 0     18.7  2024     12  lowTempSeason        No
# 1     18.7  2024     12  lowTempSeason        No
# 2     21.8  2024     12  lowTempSeason        No
# 3     21.2  2024     12  lowTempSeason        No
# 4     21.2  2024     12  lowTempSeason        No
# 5     21.4  2024     12  lowTempSeason       Yes
# 6     21.9  2024     12  lowTempSeason        No
# 7     21.2  2024     12  lowTempSeason        No
# 8     20.5  2024     12  lowTempSeason        No
# 9     20.4  2024     12  lowTempSeason        No

# %% [markdown]
# ### Basic info after preprocessing:

# %%
df.describe()
# Out:
#        DayPeakGen(MW)  EveningPeakGen(MW)  MaxDemand(MW)    MaxGen(MW)  \
# count     1644.000000         1644.000000    1644.000000   1644.000000
# mean     12774.193431        14120.095499   12282.137470  14120.095499
# std       1622.972287         1532.989559    1979.530122   1532.989559
# min       7966.000000         9482.000000    7800.000000   9482.000000
# 25%      11818.000000        13169.750000   10600.000000  13169.750000
# 50%      13042.000000        14440.500000   12400.000000  14440.500000
# 75%      13925.500000        15200.250000   13900.000000  15200.250000
# max      16463.000000        17638.000000   17300.000000  17638.000000
#
#            Temp(C)         Year        Month
# count  1644.000000  1644.000000  1644.000000
# mean     27.233090  2022.167883     6.858881
# std       3.811737     1.332597     3.405918
# min      14.000000  2020.000000     1.000000
# 25%      24.800000  2021.000000     4.000000
# 50%      28.600000  2022.000000     7.000000
# 75%      30.000000  2023.000000    10.000000
# max      33.800000  2024.000000    12.000000

# %% [markdown]
# ## Now, we move on to visualization.

# %%
sns.set_palette(palette="flare")

# %% [markdown]
# ### We start with a basic pairplot to get an overall idea of the kind of data we have.

# %%
sns.pairplot(df)

# %% [markdown]
# ## Next, let's visualize each feature separately.
# ### For numerical features, we'll be plotting their distribution, and for categorical, their bar charts.

# %% [markdown]
# #### DayPeakGen(MW), numerical:

# %%
# Histogram for Day Peak Generation
sns.histplot(df['DayPeakGen(MW)'], bins=30, kde=True)
plt.xlabel('DayPeakGen(MW)')
plt.ylabel('Density')
plt.title('Histogram of Day Peak Generation with KDE')
plt.show()

# %% [markdown]
# #### EveningPeakGen(MW), numerical:

# %%
# Histogram for Evening Peak Generation
sns.histplot(df['EveningPeakGen(MW)'], bins=30, kde=True)
plt.xlabel('EveningPeakGen(MW)')
plt.ylabel('Density')
plt.title('Histogram of Evening Peak Generation with KDE')
plt.show()

# %% [markdown]
# #### MaxGeneration(MW), numerical:

# %%
# Histogram for Max Generation
#Target Variable
sns.histplot(df['MaxGen(MW)'], bins=30, kde=True)
plt.xlabel('MaxGen(MW)')
plt.ylabel('Density')
plt.title('Histogram of Max Generation with KDE')
plt.show()

# %% [markdown]
# #### MaxDemand(MW), numerical:

# %%
# Histogram for Max Demand
sns.histplot(df['MaxDemand(MW)'], bins=30, kde=True)  #kde=True adds a smooth density curve
plt.xlabel('Max Demand (MW)')
plt.ylabel('Count')
plt.title('Histogram of Max Demand with KDE')
plt.show()

# %% [markdown]
# #### Temp(C), numerical:

# %%
# Histogram for Temperature
sns.histplot(df['Temp(C)'], bins=30, kde=True)
plt.xlabel('Temperature (°C)')
plt.ylabel('Density')
plt.title('Histogram of Temperature with KDE')
plt.show()

# %% [markdown]
# ### We may detect outliers in the data by using a box-and-whiskers plot.

# %%
# Plot boxplots for outlier detection
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sns.boxplot(x=df['Temp(C)'])
plt.title('Boxplot of Temperature')


plt.show()

# %%
Q1 = df["Temp(C)"].quantile(0.25)
Q3 = df["Temp(C)"].quantile(0.75)
IQR = Q3 - Q1

# Define lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = df[(df["Temp(C)"] < lower_bound) | (df["Temp(C)"] > upper_bound)]

# Count the number of outliers
num_outliers = outliers.shape[0]

print(f"Number of outliers in Temp(C): {num_outliers}")
# Out:
# Number of outliers in Temp(C): 14

# %% [markdown]
# #### Season, categorical:

# %%
# Bar chart for Season
sns.countplot(x='Season', data=df)
plt.xlabel('Season')
plt.ylabel('Count')
plt.title('Count of Records by Season')
plt.show()

# %% [markdown]
# #### IsHoliday, categorical:

# %%
# Bar chart for IsHoliday
sns.countplot(x='IsHoliday', data=df)
plt.xlabel('IsHoliday')
plt.ylabel('Count')
plt.title('Count of Records by IsHoliday')
plt.show()

# %%
sns.boxplot(x='Season', y='MaxDemand(MW)', data=df)
plt.title("Max Demand Variation Across Seasons")
plt.show()

# %% [markdown]
# ## To detect trends in Electricity Generation, we may plot the MaxDemand and MaxGen over time.

# %%
plt.figure(figsize=(12, 5))

plt.plot(df.index, df['MaxDemand(MW)'], label="Max Demand (MW)")
plt.plot(df.index, df['MaxGeneration(MW)'], label="Max Generation (MW)")

plt.xlabel('Date')
plt.ylabel('MW')

plt.legend()
plt.title('Max Demand vs Max Generation Over Time')
plt.show()

# %% [markdown]
# ### It will also be useful to view the variation of Electricity demanded over the two season categories.

# %% [markdown]
# ### Furthermore, we can get granular with the time analysis as we plot the demanded electricty for each year, by month.

# %%
monthly_avg = df.groupby("Month")["MaxDemand(MW)"].mean()
plt.figure(figsize=(10,5))
plt.plot(monthly_avg.index, monthly_avg.values, marker='o', linestyle='-')
plt.xlabel("Month")
plt.ylabel("Average Max Demand (MW)")
plt.title("Average Monthly Demand Trend")
plt.show()

# %% [markdown]
# ## Finally, we have a correlation matrix to help us find relevant features.

# %%
# Generate a heatmap for the dataset

plt.figure(figsize=(12, 8))
numeric_df = df.select_dtypes(include=[np.number]) # Exclude non-numeric columns

sns.heatmap(numeric_df.corr(), annot=True, cmap='flare', linewidths=0.5)
plt.title('Heatmap of Dataset Features')
plt.show()
